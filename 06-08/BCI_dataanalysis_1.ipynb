# %% [markdown]
# <a href="https://colab.research.google.com/github/namnitha/Dissertation/blob/master/06-08/BCI_dataanalysis_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mne
# Out:
# Collecting mne
#   Downloading https://files.pythonhosted.org/packages/92/ab/9b79f927b599da515335afb4b666a7bb336930a6d8345e7b483a9980a9c1/mne-0.20.7-py3-none-any.whl (6.6MB)
#      |████████████████████████████████| 6.6MB 7.3MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from mne) (1.18.5)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from mne) (1.4.1)
# Installing collected packages: mne
# Successfully installed mne-0.20.7

# %%
pip install neo
# Out:
# Collecting neo
#   Downloading https://files.pythonhosted.org/packages/9c/4a/b4922f90db90c2b1a8c77fdc39a4a1ad15d386d1a167c1424405cab2eeaa/neo-0.8.0.tar.gz (2.1MB)
#      |████████████████████████████████| 2.1MB 8.2MB/s
# Requirement already satisfied: numpy>=1.7.1 in /usr/local/lib/python3.6/dist-packages (from neo) (1.18.5)
# Collecting quantities>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/2b/4f/2e8ce7d6c16fb07c43036f8539962322b2bf241e7397e87f318a1aa2f7c4/quantities-0.12.4.tar.gz (83kB)
#      |████████████████████████████████| 92kB 7.7MB/s
# Building wheels for collected packages: neo, quantities
#   Building wheel for neo (setup.py) ... done
#   Created wheel for neo: filename=neo-0.8.0-cp36-none-any.whl size=558935 sha256=89022a7fa2890c369538781657e84d89492aa61e76f088cc65d3f4797801b890
#   Stored in directory: /root/.cache/pip/wheels/28/35/f4/273432a8b9eb6c9182e666e9630cc92c221dabe81462606d9c
#   Building wheel for quantities (setup.py) ... done
#   Created wheel for quantities: filename=quantities-0.12.4-cp36-none-any.whl size=79167 sha256=e92706c90a6c39378ab40a77faf6b6201074307a02ab8e28bae86a9e59db093e
#   Stored in directory: /root/.cache/pip/wheels/2c/27/a5/62fb2a57d167d7b7164278de7399ba1504321c1d6c3a3802d5
# Successfully built neo quantities
# Installing collected packages: quantities, neo
# Successfully installed neo-0.8.0 quantities-0.12.4

# %%
pip install BCI2kReader
# Out:
# Collecting BCI2kReader
#   Downloading https://files.pythonhosted.org/packages/e7/80/313305c8a7732efb743b05790b9ec17ee4ca25be1f9017c316dfce2ce509/BCI2kReader-0.32.dev0-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from BCI2kReader) (1.18.5)
# Installing collected packages: BCI2kReader
# Successfully installed BCI2kReader-0.32.dev0

# %%
import neo
import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from BCI2kReader import BCI2kReader as b2k

# %%
data = b2k.BCI2kReader('/content/VPtaqS001R01.dat')

# %%
signals = data.signals
print(signals.shape)
# Out:
# (68, 96260)

# %%
#sampling rate
data.samplingrate
# Out:
# 500.0

# %%
#reads the whole file and stores it in a numpy matrix channels
my_signals = data.signals

#reads all states as a dictionary
my_states= data.states
my_states['Running']
# Out:
# array([[0, 0, 0, ..., 1, 1, 1]], dtype=int32)

# %%
print(my_states)
# Out:
# {'StimulusCodeRes': array([[0, 0, 0, ..., 0, 0, 0]], dtype=int32), 'StimulusTypeRes': array([[0, 0, 0, ..., 0, 0, 0]], dtype=int32), 'SourceTime': array([[ 5509,  5509,  5509, ..., 11077, 11077, 11077]], dtype=int32), 'Running': array([[0, 0, 0, ..., 1, 1, 1]], dtype=int32), 'Recording': array([[0, 0, 0, ..., 1, 1, 1]], dtype=int32), 'StimulusCode': array([[0, 0, 0, ..., 0, 0, 0]], dtype=int32), 'StimulusType': array([[0, 0, 0, ..., 0, 0, 0]], dtype=int32), 'Flashing': array([[0, 0, 0, ..., 0, 0, 0]], dtype=int32), 'SelectedTarget': array([[5, 5, 5, ..., 6, 6, 6]], dtype=int32), 'SelectedRow': array([[1, 1, 1, ..., 2, 2, 2]], dtype=int32), 'SelectedColumn': array([[5, 5, 5, ..., 1, 1, 1]], dtype=int32), 'PhaseInSequence': array([[2, 2, 2, ..., 3, 3, 3]], dtype=int32), 'StimulusTime': array([[ 5478,  5478,  5478, ..., 11046, 11046, 11046]], dtype=int32)}

# %%
print('Stimulus Code = ', my_states['StimulusCode'])
plt.title('Stimulus Code')
plt.plot(my_states['StimulusCode'][0])
plt.show()

print('Stimulus Type = ', my_states['StimulusType'])
plt.title('Stimulus Type')
plt.plot(my_states['StimulusType'][0])
plt.show()

print('Stimulus Time = ', my_states['StimulusTime'])
plt.title('Stimulus Time')
plt.plot(my_states['StimulusTime'][0])
plt.show()

#Stimulus time and Source time are different
print('Source Time = ', my_states['SourceTime'])
plt.title('Source Time')
plt.plot(my_states['SourceTime'][0])
plt.show()
# Out:
# Stimulus Code =  [[0 0 0 ... 0 0 0]]
# Stimulus Type =  [[0 0 0 ... 0 0 0]]
# Stimulus Time =  [[ 5478  5478  5478 ... 11046 11046 11046]]
# Source Time =  [[ 5509  5509  5509 ... 11077 11077 11077]]

# %%
#creating MNE datastructures
#Creating Raw objects and info

info = mne.create_info(
    ch_names=['FP1', 'Fpz', 'FP2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FT9', 'FT7', 
          'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'FT8', 'FT10', 'T7', 
          'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP9', 'TP7', 
          'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'TP8', 'TP10', 'P9', 
          'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'P10', 
          'PO7', 'P05', 'P01', 'POz', 'P02', 'P06', 'PO8', 'O1', 'Oz', 'O2', 
          'O9', 'Iz', 'O10', 'NA', 'NA', 'NA', 'NA', 'NA'],
    ch_types=['eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg',
          'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 
          'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 
          'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 
          'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 
          'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 
          'eeg', 'eeg', 'eeg', 'eog', 'eog', 'eog', 'eog', 'eog'],
    sfreq=100)
print(info)
raw = mne.io.RawArray(my_signals, info)
print(raw)
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: FP1, Fpz, FP2, F7, F3, Fz, F4, F8, FT9, FT7, FC5, FC3, FC1, FCz, ...
#  chs: 63 EEG, 5 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 50.0 Hz
#  meas_date: unspecified
#  nchan: 68
#  projs: []
#  sfreq: 100.0 Hz
# >
# Creating RawArray with float64 data, n_channels=68, n_times=96260
#     Range : 0 ... 96259 =      0.000 ...   962.590 secs
# Ready.
# <RawArray | 68 x 96260 (962.6 s), ~50.1 MB, data loaded>
# <ipython-input-12-0860ec85aee9>:19: RuntimeWarning: Channel names are not unique, found duplicates for: {'NA'}. Applying running numbers for duplicates.
#   sfreq=100)

# %%
d, t = raw[raw.ch_names.index('Cz'), :]
d.shape
# Out:
# (1, 96260)

# %%
raw.ch_names.index('Cz')
# Out:
# 23

# %%
raw.plot(n_channels=15, title='Data from arrays', scalings='auto', 
                show=True, block=True)

# %%
st = my_states['StimulusType'][0]
LS = 0  #last state
isFirst = True
for i in range(len(st)):    
    if(LS != st[i] and st[i] == 1):
        print('state change detected')
        if isFirst:
            events = np.array([i, 0, st[i]])
            isFirst = False
        else:
            events = np.vstack((events, np.array([i, 0, st[i]])))
    LS = st[i] 
#print(events)
print('Found %s events, first five:' % len(events))
print(events[:5])
# Out:
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# Found 150 events, first five:
# [[ 860    0    1]
#  [1580    0    1]
#  [2300    0    1]
#  [2900    0    1]
#  [3260    0    1]]

# %% [markdown]
# The event list contains three columns. The first column corresponds to sample number. To convert this to seconds, you should divide the sample number by the used sampling frequency. The second column is reserved for the old value of the trigger channel at the time of transition, but is currently not in use. The third column is the trigger id (amplitude of the pulse).

# %%
plt.title('Events extracted from Stimulus Type')
plt.plot(events)
# Out:
# [<matplotlib.lines.Line2D at 0x7f0834367710>,
#  <matplotlib.lines.Line2D at 0x7f0832956780>,
#  <matplotlib.lines.Line2D at 0x7f08329568d0>]

# %%
# for fixed size events no start time before and after event
tmin = 0.
tmax = 0.99  # inclusive tmax, 1 second epochs

#Creating Epochs
epochs = mne.Epochs(raw, events=events, event_id= None, tmin=tmin, 
                    tmax=tmax, baseline=None, verbose=True)

#Plotting Epochs
epochs.plot(scalings='auto', show=True, block=True)
# Out:
# 150 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 150 events and 100 original time points ...
# 0 bad epochs dropped
# Loading data for 150 events and 100 original time points ...
# Loading data for 20 events and 100 original time points ...

# %% [markdown]
# Averaging the epochs to get the evoked response

# %%
# averaging the epochs to get the evoked response
picks = mne.pick_types(epochs.info, eeg=True, eog=True)
evoked = epochs.average(picks=picks)
evoked.plot(time_unit='s')

# %% [markdown]
# Averaging the epochs for selected channels.

# %%
# Averaging the epochs for selected channels
picks = [raw.ch_names.index(ch) for ch in ['Cz']] 
evoked = epochs.average(picks=picks)

title = 'Averaged epoch response of Channel "Cz" '
evoked.plot(titles=dict(eeg=title), time_unit='s')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
#For channel FP1
picks = [raw.ch_names.index(ch) for ch in ['FP1']] 
evoked = epochs.average(picks=picks)

title = 'Averaged epoch response of Channel "Fp1" '
evoked.plot(titles=dict(eeg=title), time_unit='s')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.

# %%
evoked.save('avg_epoch_FP1.fif')
# Out:
# <ipython-input-22-53e86f137048>:1: RuntimeWarning: This filename (avg_epoch_FP1.fif) does not conform to MNE naming conventions. All evoked files should end with -ave.fif, -ave.fif.gz, _ave.fif or _ave.fif.gz
#   evoked.save('avg_epoch_FP1.fif')

# %% [markdown]
# ##Taking events from Stimulus code and Stimulus type

# %%
st = my_states['StimulusType'][0]
sc = my_states['StimulusCode'][0]
LS = 0  #last state
isFirst = True
for i in range(len(st)), j in range(len(sc)):
    #if((LS != sc[j] and sc[j] !=0) and (LS != st[i] and st[i] == 0)):
    if(LS != sc[j] and sc[j] !=0 and st[i] == 0):
       print('state change detected')
       if isFirst:
           events = np.array([[j, 0, sc[j]], [i, 0, st[i]]])
           isFirst = False
       else:
           events = np.vstack((events, np.array([[j, 0, sc[j]], [i, 0, st[i]]])))
    #LS = sc[j] = st[i]
    #break
#print(events)
print('Found %s events, first five:' % len(events))
print(events[:5])
#Non-attended
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-644977c4aa81> in <module>()
#       3 LS = 0  #last state
#       4 isFirst = True
# ----> 5 for i in range(len(st)), j in range(len(sc)):
#       6     #if((LS != sc[j] and sc[j] !=0) and (LS != st[i] and st[i] == 0)):
#       7     if(LS != sc[j] and sc[j] !=0 and st[i] == 0):
#
# NameError: name 'j' is not defined

# %%
st = my_states['StimulusType'][0]
sc = my_states['StimulusCode'][0]
LS = 0  #last state
isFirst = True
#---------------------------Attended-------------------------
#Targets
for i in range(len(st)):    
    if(LS != st[i] and st[i] == 1):
        print('state change detected')
        if isFirst:
            events1 = np.array([i, 0, st[i]])
            isFirst = False
        else:
            events1 = np.vstack((events1, np.array([i, 0, st[i]])))
    LS = st[i] 
#print(events)
print('Found %s events, first five:' % len(events1))
print(events1[:10])

#---------------------------Non attended-------------------------
#StimulusType
for i in range(len(st)):    
    if(LS != st[i] and st[i] == 0):
        print('state change detected')
        if isFirst:
            events1 = np.array([i, 0, st[i]])
            isFirst = False
        else:
            events1 = np.vstack((events1, np.array([i, 0, st[i]])))
    LS = st[i] 
#print(events)
print('Found %s events, first five:' % len(events1))
print(events1[:10])


#Stimulus Code
for i in range(len(sc)):    
    if(LS != sc[i] and sc[i] != 0):
        print('state change detected')
        if isFirst:
            events1 = np.array([i, 0, sc[i]])
            isFirst = False
        else:
            events1 = np.vstack((events1, np.array([i, 0, sc[i]])))
    LS = sc[i] 
#print(events)
print('Found %s events, first five:' % len(events1))
print(events1[:10])
# Out:
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# Found 150 events, first five:
# [[ 860    0    1]
#  [1580    0    1]
#  [2300    0    1]
#  [2900    0    1]
#  [3260    0    1]
#  [4220    0    1]
#  [4340    0    1]
#  [4940    0    1]
#  [5660    0    1]
#  [6620    0    1]]
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# Found 300 events, first five:
# [[ 860    0    1]
#  [1580    0    1]
#  [2300    0    1]
#  [2900    0    1]
#  [3260    0    1]
#  [4220    0    1]
#  [4340    0    1]
#  [4940    0    1]
#  [5660    0    1]
#  [6620    0    1]]
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# state change detected
# Found 1050 events, first five:
# [[ 860    0    1]
#  [1580    0    1]
#  [2300    0    1]
#  [2900    0    1]
#  [3260    0    1]
#  [4220    0    1]
#  [4340    0    1]
#  [4940    0    1]
#  [5660    0    1]
#  [6620    0    1]]

# %%
print('Found %s events' % len(events1))
print('All Events', events1)

plt.title('Events extracted from Stimulus Type and Stimulus Code')
plt.plot(events1)
# Out:
# Found 1050 events
# All Events [[  860     0     1]
#  [ 1580     0     1]
#  [ 2300     0     1]
#  ...
#  [95340     0     3]
#  [95460     0     5]
#  [95580     0     9]]
# [<matplotlib.lines.Line2D at 0x7f0831b4fcf8>,
#  <matplotlib.lines.Line2D at 0x7f0831b23908>,
#  <matplotlib.lines.Line2D at 0x7f0831b23a58>]

# %%
# for fixed size events no start time before and after event
tmin = 0.
tmax = 0.99  # inclusive tmax, 1 second epochs

#Creating Epochs
epochs1 = mne.Epochs(raw, events=events1, event_id= None, tmin=tmin, 
                    tmax=tmax, baseline=None, verbose=True, event_repeated='drop' ) #

#Plotting Epochs
epochs1.plot(scalings='auto', show=True, block=True)
# Out:
# Multiple event values for single event times found. Keeping the first occurrence and dropping all others.
# 900 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Loading data for 900 events and 100 original time points ...
# 0 bad epochs dropped
# Loading data for 900 events and 100 original time points ...
# Loading data for 20 events and 100 original time points ...

# %%
# averaging the epochs to get the evoked response
picks1 = mne.pick_types(epochs1.info, eeg=True, eog=True)
evoked = epochs1.average(picks=picks1)
evoked.plot(time_unit='s')

# %%
# Averaging the epochs for selected channels
picks = [raw.ch_names.index(ch) for ch in ['Cz']] 
evoked = epochs1.average(picks=picks)

title = 'Averaged epoch response of Channel "Cz" '
evoked.plot(titles=dict(eeg=title), time_unit='s')
# Out:
# Need more than one channel to make topography for eeg. Disabling interactivity.
